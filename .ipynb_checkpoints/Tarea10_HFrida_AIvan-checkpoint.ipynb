# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Iván Andrés Arellano Ruelas, Frida María Hernández López.
#
# **Fecha:** 27 de noviembre del 2021.
#
# **Expediente:** 714383, 720476.
#
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Link Github:** https://github.com/FridaHernandezL/Tarea10_HFrida_AIvan
#
# # Tarea 10: Clase 24

# %% [markdown]
# Realizar la valuación de las opciones barrera para las acciones de Microsoft, siguiendo los siguientes lineamientos:
# 1. Realizar la valuación para el tipo de opción barrera 'CALL'- down-and-out, usando la suposición de rendimientos normales y usando el método del histograma. Para ambas valuaciones, comparar los resultados de la evaluación obtenida con los resultados obtenidos por la valuación Europea. Como se realizó en clase.
# 2. Repetir el inciso anterior pero en esta ocasión para el caso de 'PUT'- Up-and-out.
#
# **Nota:** Analice los datos descargados y según el método ya sea `down-and-out` o `Up-and-out` defina un strike price usando la volatility smile vista en la clase de opciones europeas y basado en el spot price y el strike defina una barrera adecuada.
#
# Se habilitará un enlace en canvas para subir un cuaderno de python, con la solución.
#
# **Criterio de revisión.**
#
# > Se te calificará de acuerdo a los resultados finales que reportes, basados en tu análisis.

# %% [markdown]
# #### Código de solución `ESTUDIANTE 1: FRIDA HERNÁNDEZ`

# %%
#importar los paquetes que se van a usar
import pandas as pd
import pandas_datareader.data as web
import numpy as np
from sklearn.neighbors import KernelDensity
import datetime
from datetime import datetime, timedelta
import scipy.stats as st
import scipy as sp # Histograma de rendimientos  sp
import scipy.optimize as optimize
import scipy.cluster.hierarchy as hac
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date
# %matplotlib inline

# %%
# Calculation of log-returns
def calc_daily_ret(closes):
    return np.log(closes/closes.shift(1)).dropna()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data = pd.read_csv('WMT.csv')
data=data.set_index('Date')
closes=pd.DataFrame(data)
closes.head()
# Out:
#             Adj Close
# Date
# 03/01/2017     62.291
# 04/01/2017     62.654
# 05/01/2017     62.790
# 06/01/2017     61.928
# 09/01/2017     62.337

# %% [markdown]
# ### Histograma de Rendimientos

# %%
ret_WMT = calc_daily_ret(closes.iloc[:,0])
mu = ret_WMT.mean()
sigma = ret_WMT.std()
r = 0.0024/360 # Daily Treasury Yield Curve Rates al 24-nov
mu, sigma, r
# Out:
# (0.0006938175288983266, 0.013686282734245046, 6.666666666666666e-06)

# %%
# Centro mis datos en mi tasa libre de riesgo
freq, values = np.histogram(ret_WMT-mu+r, bins=10000)
# freq = freq.astype('float32')
prob = freq/np.sum(freq)

# %% [markdown]
# #### 1. Opción barrera 'CALL'- down-and-out

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Datos de la opción y del día de actual
today = pd.Timestamp(date.today())
expiry = '2022-03-18'

# Fechas desde el día de hoy hasta la fecha de cierre del contrato (considerando unicamente los días hábiles)
dates = pd.date_range(start=today, end=expiry, freq='B')

# Cantidad de escenarios a simular para el método de montecarlo
ndays = len(dates)
nscen = 10000

K = 160
S0 = closes.iloc[-1,0]

ret = np.random.choice(values[1:], (ndays,nscen), p=prob)
sim_ret_hist = pd.DataFrame(ret, index=dates)
sim_closes_hist = S0*np.exp(sim_ret_hist.cumsum())
sim_closes_hist.iloc[0,:]=S0

# %%
strike = pd.DataFrame(K*np.ones(ndays*nscen).reshape((ndays,nscen)), index=dates)
call_hist = pd.DataFrame({'Prima':np.exp(-r*ndays)*np.fmax(sim_closes_hist-strike,np.zeros(ndays*nscen).reshape((ndays,nscen))).T.mean()}, index=dates)
call_hist.plot();

# %%
prima=call_hist.iloc[-1,0]
prima
# Out:
# 3.103065969513605

# %%
# Datos de la opción y del día de actual
today = pd.Timestamp(date.today())
expiry = expiry

# Fechas desde el día de hoy hasta la fecha de cierre del contrato (considerando unicamente los días hábiles)
dates = pd.date_range(start = today, end = expiry, freq='B')

# Cantidad de escenarios a simular para el método de montecarlo
ndays = len(dates)
nscen = 10000

K = 160
S0 = closes.iloc[-1,0]

sim_ret = pd.DataFrame(sigma*np.random.randn(ndays,nscen)+r,index=dates)
sim_closes = S0*np.exp(sim_ret.cumsum())
sim_closes.iloc[0,:] = S0
sim_closes
# Out:
#                0        1        2     ...     9997     9998     9999
# 2021-11-26  146.540  146.540  146.540  ...  146.540  146.540  146.540
# 2021-11-29  141.981  142.351  148.376  ...  146.863  151.375  147.987
# 2021-11-30  141.256  143.108  149.214  ...  145.966  150.027  147.662
# 2021-12-01  141.136  144.897  150.800  ...  146.553  148.138  147.972
# 2021-12-02  139.378  143.895  154.436  ...  148.380  148.868  145.723
# ...             ...      ...      ...  ...      ...      ...      ...
# 2022-03-14  127.111  145.827  169.153  ...  159.531  164.797  180.317
# 2022-03-15  125.626  146.405  168.420  ...  161.200  164.090  179.706
# 2022-03-16  124.774  143.983  168.451  ...  158.556  167.049  178.243
# 2022-03-17  126.122  144.641  168.314  ...  161.269  167.523  180.781
# 2022-03-18  128.744  144.416  165.917  ...  159.528  166.326  178.747
#
# [81 rows x 10000 columns]

# %%
K,S0
# Out:
# (160, 146.53999299999998)

# %%
# Precio barrera
B = 142

# Función de activación (knock-in)
# Si en algún momento el precio toca la barrera la opción se desactiva
I = (sim_closes > B).cumprod(axis=0)  > 0
I
# Out:
#              0      1     2     ...  9997   9998  9999
# 2021-11-26   True   True  True  ...  True   True  True
# 2021-11-29  False   True  True  ...  True   True  True
# 2021-11-30  False   True  True  ...  True   True  True
# 2021-12-01  False   True  True  ...  True   True  True
# 2021-12-02  False   True  True  ...  True   True  True
# ...           ...    ...   ...  ...   ...    ...   ...
# 2022-03-14  False  False  True  ...  True  False  True
# 2022-03-15  False  False  True  ...  True  False  True
# 2022-03-16  False  False  True  ...  True  False  True
# 2022-03-17  False  False  True  ...  True  False  True
# 2022-03-18  False  False  True  ...  True  False  True
#
# [81 rows x 10000 columns]

# %%
closes.plot()

# %%
# Definir barrera
B = B
# Crear función indicadora
I = (sim_closes > B).cumprod(axis=0)  > 0
# Definir strike
strike = K
# Calcular la prima de una opción Europea
call = pd.DataFrame({'Prima Europea':np.exp(-r*ndays)*np.fmax(sim_closes - strike, 0)
                     .mean(axis=1)},index=dates)
# Calcular la prima de una opción barrera
callba = pd.DataFrame({'Prima down-and-out':np.exp(-r*ndays)*(I * np.fmax(sim_closes - strike, 0))
                       .mean(axis=1)},index=dates)
# Graficar el resultado de las dos primas previamente valuadas
ax = callba.plot();
call.plot(ax=ax);

# %%
call.iloc[-1], callba.iloc[-1]
# Out:
# (Prima Europea    3.019
#  Name: 2022-03-18 00:00:00, dtype: float64,
#  Prima down-and-out    2.144
#  Name: 2022-03-18 00:00:00, dtype: float64)

# %% [markdown]
# #### 2. Opción barrera 'PUT'- up-and-out

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Datos de la opción y del día de actual
today = pd.Timestamp(date.today())
expiry = '2022-03-18'

# Fechas desde el día de hoy hasta la fecha de cierre del contrato (considerando unicamente los días hábiles)
dates = pd.date_range(start=today, end=expiry, freq='B')

# Cantidad de escenarios a simular para el método de montecarlo
ndays = len(dates)
nscen = 10000

K = 140
S0 = closes.iloc[-1,0]

ret = np.random.choice(values[1:], (ndays,nscen), p=prob)
sim_ret_hist = pd.DataFrame(ret, index=dates)
sim_closes_hist = S0*np.exp(sim_ret_hist.cumsum())
sim_closes_hist.iloc[0,:]=S0

# %%
put_hist=pd.DataFrame({'Prima':np.exp(-r*ndays)*np.fmax(strike-sim_closes_hist,np.zeros([ndays,nscen])).T.mean()},index=dates)
put_hist.plot();

# %%
prima=call_hist.iloc[-1,0]
prima, K, S0
# Out:
# (3.103065969513605, 140, 146.53999299999998)

# %%
# Precio barrera
B = 150

# Función  (Put  up and out )
# Si en algún momento el precio toca la barrera la opción se desactiva
I = (sim_closes < B).cumprod(axis=0)  > 0
I
# Out:
#              0     1      2     ...   9997   9998   9999
# 2021-11-26   True  True   True  ...   True   True   True
# 2021-11-29   True  True   True  ...   True  False   True
# 2021-11-30   True  True   True  ...   True  False   True
# 2021-12-01   True  True  False  ...   True  False   True
# 2021-12-02   True  True  False  ...   True  False   True
# ...           ...   ...    ...  ...    ...    ...    ...
# 2022-03-14  False  True  False  ...  False  False  False
# 2022-03-15  False  True  False  ...  False  False  False
# 2022-03-16  False  True  False  ...  False  False  False
# 2022-03-17  False  True  False  ...  False  False  False
# 2022-03-18  False  True  False  ...  False  False  False
#
# [81 rows x 10000 columns]

# %%
# Definir barrera
B = B
# Crear función indicadora
I = (sim_closes < B).cumprod(axis=0)  > 0
# Definir strike
strike = K
# Calcular la prima de una opción Europea
put = pd.DataFrame({'Prima Europea':np.exp(-r*ndays)*np.fmax(strike-sim_closes, 0)
                     .mean(axis=1)},index=dates)
# Calcular la prima de una opción barrera
putba = pd.DataFrame({'Prima up and out ':np.exp(-r*ndays)*(I * np.fmax(strike-sim_closes, 0))
                       .mean(axis=1)},index=dates)
# Graficar el resultado de las dos primas previamente valuadas
ax = putba.plot();
put.plot(ax=ax);

# %%
putba.iloc[-1], put.iloc[-1]
# Out:
# (Prima up and out     2.054
#  Name: 2022-03-18 00:00:00, dtype: float64,
#  Prima Europea    3.779
#  Name: 2022-03-18 00:00:00, dtype: float64)

# %% [markdown]
# #### Código de solución `ESTUDIANTE 2: IVAN ARELLANO`

# %%
#importar los paquetes que se van a usar
import pandas as pd
import pandas_datareader.data as web
import numpy as np
from sklearn.neighbors import KernelDensity
import datetime
from datetime import datetime, timedelta
import scipy.stats as st
import scipy as sp
import scipy.optimize as optimize
import scipy.cluster.hierarchy as hac
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date
# %matplotlib inline
#algunas opciones para Python
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 6)
pd.set_option('display.max_rows', 10)
pd.set_option('display.width', 78)
pd.set_option('precision', 3)

# %%
# Función para descargar precios de cierre ajustados:
def get_adj_closes(tickers, start_date=None, end_date=None):
    # Fecha inicio por defecto (start_date='2010-01-01') y fecha fin por defecto (end_date=today)
    # Descargamos DataFrame con todos los datos
    closes = web.DataReader(name=tickers, data_source='yahoo', start=start_date, end=end_date)
    # Solo necesitamos los precios ajustados en el cierre
    closes = closes['Adj Close']
    # Se ordenan los índices de manera ascendente
    closes.sort_index(inplace=True)
    return closes

####### Calculation of log-returns
def calc_daily_ret(closes):
    return np.log(closes/closes.shift(1)).dropna()

# %%
closes = get_adj_closes(['MSFT'], '2017-01-01')
closes_MSFT = closes.loc[:,'MSFT']
ret_MSFT = calc_daily_ret(closes_MSFT)
closes_MSFT,closes_MSFT[-1]
# Out:
# (Date
#  2017-01-03     58.186
#  2017-01-04     57.925
#  2017-01-05     57.925
#  2017-01-06     58.427
#  2017-01-09     58.241
#                 ...
#  2021-11-18    341.270
#  2021-11-19    343.110
#  2021-11-22    339.830
#  2021-11-23    337.680
#  2021-11-24    337.910
#  Name: MSFT, Length: 1234, dtype: float64,
#  337.9100036621094)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Histograma de rendimientos

# %%
mu = ret_MSFT.mean()
sigma = ret_MSFT.std()
r = 0.0021/360 # Tasa utilizada en clase
mu, sigma, r
# Out:
# (0.0014267178176682847, 0.01732629832479977, 5.833333333333333e-06)

# %%
# Centro mis datos en mi tasa libre de riesgo
freq, values = np.histogram(ret_MSFT-mu+r, bins=10000)
# freq = freq.astype('float32')
prob = freq/np.sum(freq)

# %%
# Datos de la opción y del día de actual
today = pd.Timestamp(date.today())
expiry = '2022-01-21'

# Fechas desde el día de hoy hasta la fecha de cierre del contrato (considerando unicamente los días hábiles)
dates = pd.date_range(start=today, end=expiry, freq='B')

# Cantidad de escenarios a simular para el método de montecarlo
ndays = len(dates)
nscen = 10000

K = 405
S0 = closes_MSFT.iloc[-1]

ret = np.random.choice(values[1:], (ndays,nscen), p=prob)
sim_ret_hist = pd.DataFrame(ret, index=dates)
sim_closes_hist = S0*np.exp(sim_ret_hist.cumsum())
sim_closes_hist.iloc[0,:]=S0

# %%
strike = pd.DataFrame(K*np.ones([ndays,nscen]),index=dates)
call_hist=pd.DataFrame({'Prima':np.exp(-r*ndays)*np.fmax(sim_closes_hist-strike,np.zeros([ndays,nscen])).T.mean()},index=dates)
call_hist.plot();

# %%
call_hist.iloc[-1]
# Out:
# Prima    1.177
# Name: 2022-01-21 00:00:00, dtype: float64

# %% [markdown]
# #  opción barrera 'CALL'- down-and-out (Para MSFT CON STRIKE DE 405)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Datos de la opción y del día de actual
today = pd.Timestamp(date.today())
expiry = expiry

# Fechas desde el día de hoy hasta la fecha de cierre del contrato (considerando unicamente los días hábiles)
dates = pd.date_range(start = today, end = expiry, freq='B')

# Cantidad de escenarios a simular para el método de montecarlo
ndays = len(dates)
nscen = 10000

K = 405
S0 = closes_MSFT.iloc[-1]

sim_ret = pd.DataFrame(sigma*np.random.randn(ndays,nscen)+r,index=dates)
sim_closes = S0*np.exp(sim_ret.cumsum())
sim_closes.iloc[0,:] = S0

# %%
sim_closes
# Out:
#                0        1        2        3        4        5        6     \
# 2021-11-25  337.910  337.910  337.910  337.910  337.910  337.910  337.910
# 2021-11-26  321.080  338.377  329.978  342.510  346.618  331.140  336.075
# 2021-11-29  320.745  339.351  331.457  340.967  351.183  334.865  336.526
# 2021-11-30  322.873  336.140  323.362  340.500  352.715  330.270  322.114
# 2021-12-01  315.435  340.537  333.178  338.861  350.284  320.276  328.746
# ...             ...      ...      ...      ...      ...      ...      ...
# 2022-01-17  300.149  348.367  320.172  341.179  349.082  365.208  351.852
# 2022-01-18  299.063  350.370  320.281  345.753  345.631  373.146  352.039
# 2022-01-19  303.732  355.656  316.999  349.695  335.445  374.007  350.630
# 2022-01-20  303.083  358.723  310.640  350.042  338.179  374.596  341.960
# 2022-01-21  306.109  369.138  308.309  358.477  335.670  383.223  345.141
#
#             ...     9993     9994     9995     9996     9997     9998  \
# 2021-11-25  ...  337.910  337.910  337.910  337.910  337.910  337.910
# 2021-11-26  ...  343.632  348.698  318.313  320.717  352.617  338.657
# 2021-11-29  ...  337.600  353.667  314.723  334.355  356.349  340.919
# 2021-11-30  ...  329.745  347.630  322.777  334.738  358.477  329.714
# 2021-12-01  ...  324.673  342.393  319.030  332.573  360.971  328.500
# ...         ...      ...      ...      ...      ...      ...      ...
# 2022-01-17  ...  322.880  313.091  302.588  348.717  336.864  353.664
# 2022-01-18  ...  319.318  310.202  300.780  343.424  337.859  358.742
# 2022-01-19  ...  313.022  304.593  296.776  331.304  330.084  354.493
# 2022-01-20  ...  324.218  297.416  307.407  327.910  333.446  359.846
# 2022-01-21  ...  328.934  300.842  317.734  322.876  331.801  361.141
#
#                9999
# 2021-11-25  337.910
# 2021-11-26  330.812
# 2021-11-29  323.259
# 2021-11-30  324.753
# 2021-12-01  328.771
# ...             ...
# 2022-01-17  340.927
# 2022-01-18  336.749
# 2022-01-19  335.131
# 2022-01-20  332.767
# 2022-01-21  335.447
#
# [42 rows x 10000 columns]

# %%
pd.set_option('display.max_columns', 15)

# Precio barrera
B = 300

# Función de activación (knock-in)
# Si en algún momento el precio toca la barrera la opción se desactiva
I = (sim_closes > B).cumprod(axis=0)  > 0
I
# Out:
#              0     1      2     3     4     5     6     ...  9993   9994  \
# 2021-11-25   True  True   True  True  True  True  True  ...  True   True
# 2021-11-26   True  True   True  True  True  True  True  ...  True   True
# 2021-11-29   True  True   True  True  True  True  True  ...  True   True
# 2021-11-30   True  True   True  True  True  True  True  ...  True   True
# 2021-12-01   True  True   True  True  True  True  True  ...  True   True
# ...           ...   ...    ...   ...   ...   ...   ...  ...   ...    ...
# 2022-01-17  False  True  False  True  True  True  True  ...  True   True
# 2022-01-18  False  True  False  True  True  True  True  ...  True   True
# 2022-01-19  False  True  False  True  True  True  True  ...  True   True
# 2022-01-20  False  True  False  True  True  True  True  ...  True  False
# 2022-01-21  False  True  False  True  True  True  True  ...  True  False
#
#              9995  9996  9997  9998  9999
# 2021-11-25   True  True  True  True  True
# 2021-11-26   True  True  True  True  True
# 2021-11-29   True  True  True  True  True
# 2021-11-30   True  True  True  True  True
# 2021-12-01   True  True  True  True  True
# ...           ...   ...   ...   ...   ...
# 2022-01-17  False  True  True  True  True
# 2022-01-18  False  True  True  True  True
# 2022-01-19  False  True  True  True  True
# 2022-01-20  False  True  True  True  True
# 2022-01-21  False  True  True  True  True
#
# [42 rows x 10000 columns]

# %%
closes_MSFT.plot()

# %%
K = 405
S0 = S0
K, S0
# Out:
# (405, 337.9100036621094)

# %%
# Definir barrera
B = 335
# Crear función indicadora
I = (sim_closes > B).cumprod(axis=0)  > 0
# Definir strike
strike = K
# Calcular la prima de una opción Europea
call = pd.DataFrame({'Prima Europea':np.exp(-r*ndays)*np.fmax(sim_closes - strike, 0)
                     .mean(axis=1)},index=dates)
# Calcular la prima de una opción barrera
callui = pd.DataFrame({'Prima down-and-out':np.exp(-r*ndays)*(I * np.fmax(sim_closes - strike, 0))
                       .mean(axis=1)},index=dates)
# Graficar el resultado de las dos primas previamente valuadas
ax = callui.plot();
call.plot(ax=ax);

# %%
call.iloc[-1]
# Out:
# Prima Europea    1.073
# Name: 2022-01-21 00:00:00, dtype: float64

# %% [markdown]
# Comparación vemos que si nos da una Prima menor, observando esta tendencia alicista teniendo en cuenta que si el precio llegará a tocar los 335 la opcción se va a desactivar, recordando un strike de 405 para enero del prox año

# %% [markdown]
# # Put  up and out  (Strike de 295)
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Datos de la opción y del día de actual
today = pd.Timestamp(date.today())
expiry = '2022-01-21'

# Fechas desde el día de hoy hasta la fecha de cierre del contrato (considerando unicamente los días hábiles)
dates = pd.date_range(start=today, end=expiry, freq='B')

# Cantidad de escenarios a simular para el método de montecarlo
ndays = len(dates)
nscen = 10000

K = 295
S0 = closes_MSFT.iloc[-1]

ret = np.random.choice(values[1:], (ndays,nscen), p=prob)
sim_ret_hist = pd.DataFrame(ret, index=dates)
sim_closes_hist = S0*np.exp(sim_ret_hist.cumsum())
sim_closes_hist.iloc[0,:]=S0

# %%
strike = pd.DataFrame(K*np.ones([ndays,nscen]),index=dates)
call_hist=pd.DataFrame({'Prima':np.exp(-r*ndays)*np.fmax(strike-sim_closes_hist,np.zeros([ndays,nscen])).T.mean()},index=dates)
call_hist.plot();

# %%
call_hist.iloc[-1]
# Out:
# Prima    1.77
# Name: 2022-01-21 00:00:00, dtype: float64

# %%
pd.set_option('display.max_columns', 15)

# Precio barrera
B = 350

# Función  (Put  up and out )
# Si en algún momento el precio toca la barrera la opción se desactiva
I = (sim_closes < B).cumprod(axis=0)  > 0
I
# Out:
#             0      1     2      3      4      5      6     ...  9993   9994  \
# 2021-11-25  True   True  True   True   True   True   True  ...  True   True
# 2021-11-26  True   True  True   True   True   True   True  ...  True   True
# 2021-11-29  True   True  True   True  False   True   True  ...  True  False
# 2021-11-30  True   True  True   True  False   True   True  ...  True  False
# 2021-12-01  True   True  True   True  False   True   True  ...  True  False
# ...          ...    ...   ...    ...    ...    ...    ...  ...   ...    ...
# 2022-01-17  True  False  True  False  False  False  False  ...  True  False
# 2022-01-18  True  False  True  False  False  False  False  ...  True  False
# 2022-01-19  True  False  True  False  False  False  False  ...  True  False
# 2022-01-20  True  False  True  False  False  False  False  ...  True  False
# 2022-01-21  True  False  True  False  False  False  False  ...  True  False
#
#             9995   9996   9997   9998   9999
# 2021-11-25  True   True   True   True   True
# 2021-11-26  True   True  False   True   True
# 2021-11-29  True   True  False   True   True
# 2021-11-30  True   True  False   True   True
# 2021-12-01  True   True  False   True   True
# ...          ...    ...    ...    ...    ...
# 2022-01-17  True  False  False  False  False
# 2022-01-18  True  False  False  False  False
# 2022-01-19  True  False  False  False  False
# 2022-01-20  True  False  False  False  False
# 2022-01-21  True  False  False  False  False
#
# [42 rows x 10000 columns]

# %%
K = 295
S0 = S0
K, S0
# Out:
# (295, 337.9100036621094)

# %%
# Definir barrera
B = 350
# Crear función indicadora
I = (sim_closes < B).cumprod(axis=0)  > 0
# Definir strike
strike = K
# Calcular la prima de una opción Europea
call = pd.DataFrame({'Prima Europea':np.exp(-r*ndays)*np.fmax(strike-sim_closes, 0)
                     .mean(axis=1)},index=dates)
# Calcular la prima de una opción barrera
callui = pd.DataFrame({'Prima up and out ':np.exp(-r*ndays)*(I * np.fmax(strike-sim_closes, 0))
                       .mean(axis=1)},index=dates)
# Graficar el resultado de las dos primas previamente valuadas
ax = callui.plot();
call.plot(ax=ax);

# %%
callui.iloc[-1]
# Out:
# Prima up and out     1.423
# Name: 2022-01-21 00:00:00, dtype: float64

# %% [markdown]
# Observo que tambien logramos una prima menor que la prima Europea
